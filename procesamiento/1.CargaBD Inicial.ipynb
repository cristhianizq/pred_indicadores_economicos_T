# %% [markdown]
# ### Carga inicial desde Backups en la base de datos
# * Falta completar nuevas bases

# %%
import pandas as pd

# %%
pd.set_option('display.max_rows', None)
pd.set_option("display.max_columns", None)
pd.set_option('display.float_format', lambda x: '%.2f' % x)

# %%
from IPython.core.display import display, HTML
display(HTML("<style>.container { width:100% !important; }</style>"))
# Out:
# <style>.container { width:100% !important; }</style>

# %% [markdown]
# ### Conexión Base de Datos

# %%
import mysql.connector
import sqlalchemy

database_username = 'root'
database_password = 'Cidifo03%%'
database_ip       = '127.0.0.1:3307'
database_name     = 'tesis'
database_connection = sqlalchemy.create_engine('mysql+mysqlconnector://{0}:{1}@{2}/{3}'.
                                               format(database_username, database_password, 
                                                      database_ip, database_name), pool_recycle=1, pool_timeout=57600).connect()

# %% [markdown]
# # Carga Backup en base de datos

# %%
df_Base_Rss = pd.read_excel (r'backupT.xlsx', sheet_name='Hoja1')
df_Base_Rss.to_sql(con=database_connection, name='t_base_rss', if_exists='replace',chunksize=100)
# Out:
# ---------------------------------------------------------------------------
# InvalidRequestError                       Traceback (most recent call last)
# C:\Users\CRISTH~1\AppData\Local\Temp/ipykernel_18196/4195470094.py in <module>
#       1 df_Base_Rss = pd.read_excel (r'backupT.xlsx', sheet_name='Hoja1')
# ----> 2 df_Base_Rss.to_sql(con=database_connection, name='T_BASE_RSS', if_exists='replace',chunksize=100)
#
# C:\ProgramData\Anaconda3\envs\T\lib\site-packages\pandas\core\generic.py in to_sql(self, name, con, schema, if_exists, index, index_label, chunksize, dtype, method)
#    2870         from pandas.io import sql
#    2871
# -> 2872         sql.to_sql(
#    2873             self,
#    2874             name,
#
# C:\ProgramData\Anaconda3\envs\T\lib\site-packages\pandas\io\sql.py in to_sql(frame, name, con, schema, if_exists, index, index_label, chunksize, dtype, method, engine, **engine_kwargs)
#     715         )
#     716
# --> 717     pandas_sql.to_sql(
# ...

# %%
df_Base_tweetter = pd.read_excel (r'backupT.xlsx', sheet_name='Hoja2')
df_Base_tweetter.to_sql(con=database_connection, name='t_base_twitter',if_exists='replace',chunksize=100)
# Out:
# C:\ProgramData\Anaconda3\envs\T\lib\site-packages\pandas\io\sql.py:1685: UserWarning: The provided table name 'T_BASE_TWEETTER' is not found exactly as such in the database after writing the table, possibly due to case sensitivity issues. Consider using lower case table names.
#   warnings.warn(msg, UserWarning)

# %%
df_Base_tweetterV2 = pd.read_csv (r'AmigosTweetter_base_V2.csv', engine='python', encoding = "ISO-8859-1", sep=';')
df_Base_tweetterV2.to_sql(con=database_connection, name='t_base_twitter', if_exists='replace',chunksize=100)

# %%
df_Base_tweetterV2
# Out:
#         screen_name           id       id_str                 name  location  \
# 0       sergiodigra          NaN          NaN                  NaN       NaN
# 1    Victor_Malagon          NaN          NaN                  NaN       NaN
# 2        jscorrales          NaN          NaN                  NaN       NaN
# 3        _minecogob          NaN          NaN                  NaN       NaN
# 4    elEconomistaes          NaN          NaN                  NaN       NaN
# 5                FT          NaN          NaN                  NaN       NaN
# 6    rodriguezbraun          NaN          NaN                  NaN       NaN
# 7         josecdiez          NaN          NaN                  NaN       NaN
# 8           suanzes          NaN          NaN                  NaN       NaN
# 9               wef          NaN          NaN                  NaN       NaN
# 10      ecofeminita          NaN          NaN                  NaN       NaN
# ...

# %%
df_RSS = pd.read_excel (r'backupT.xlsx', sheet_name='Hoja3')
df_RSS.to_sql(con=database_connection, name='t_rss', if_exists='replace',chunksize=100)
# Out:
# C:\ProgramData\Anaconda3\envs\T\lib\site-packages\pandas\io\sql.py:1685: UserWarning: The provided table name 'T_RSS' is not found exactly as such in the database after writing the table, possibly due to case sensitivity issues. Consider using lower case table names.
#   warnings.warn(msg, UserWarning)

# %%
df_RSS_TMP = pd.read_excel (r'backupT.xlsx', sheet_name='Hoja4')
df_RSS_TMP.to_sql(con=database_connection, name='r_rss_tmp', if_exists='replace',chunksize=100)
# Out:
# C:\ProgramData\Anaconda3\envs\T\lib\site-packages\pandas\io\sql.py:1685: UserWarning: The provided table name 'T_RSS_TMP' is not found exactly as such in the database after writing the table, possibly due to case sensitivity issues. Consider using lower case table names.
#   warnings.warn(msg, UserWarning)

# %%
df_TWEETS = pd.read_excel (r'backupT.xlsx', sheet_name='Hoja7')
df_TWEETS.to_sql(con=database_connection, name='t_tweets', if_exists='replace',chunksize=100)
# Out:
# C:\ProgramData\Anaconda3\envs\T\lib\site-packages\pandas\io\sql.py:1685: UserWarning: The provided table name 'T_TWEETS' is not found exactly as such in the database after writing the table, possibly due to case sensitivity issues. Consider using lower case table names.
#   warnings.warn(msg, UserWarning)

# %%
df_TWEETS_TMP = pd.read_excel (r'backupT.xlsx', sheet_name='Hoja8')
df_TWEETS_TMP.to_sql(con=database_connection, name='t_tweets_tmp', if_exists='replace',chunksize=100)
# Out:
# C:\ProgramData\Anaconda3\envs\T\lib\site-packages\pandas\io\sql.py:1685: UserWarning: The provided table name 'T_TWEETS_TMP' is not found exactly as such in the database after writing the table, possibly due to case sensitivity issues. Consider using lower case table names.
#   warnings.warn(msg, UserWarning)

# %%
database_connection.close()
